# %%
texto = '''
Este é o lenço de Marília,
pelas suas mãos lavrado,
nem a ouro nem a prata,
somente a ponto cruzado.
Este é o lenço de Marília
para o Amado.

Em cada ponta, um raminho,
preso num laço encarnado;
no meio, um cesto de flores,
por dois pombos transportado.
Não flores de amor-perfeito,
mas de malogrado!

Este é o lenço de Marília:
bem vereis que está manchado:
será do tempo perdido?
será do tempo passado?
Pela ferrugem das horas?
ou por molhado
em águas de algum arroio
singularmente salgado?

Finos azuis e vermelhos
do largo lenço quadrado,
— quem pintou nuvens tão negras
neste pano delicado,
sem dó de flores e de asas
nem do seu recado?

Este é o lenço de Marília,
por vento de amor mandado.
Para viver de suspiros
foi pela sorte fadado:
breves suspiros de amante,
— longos, de degredado!

Este é o lenço de Marília
nele vereis retratado
o destino dos amores
por um lenço atravessado:
que o lenço para os adeuses
e o pranto foi inventado.

Olhai os ramos de flores
de cada lado!
E os tristes pombos, no meio,
com o seu cestinho parado
sobre o tempo, sobre as nuvens
do mau fado!

Onde está Marília, a bela?
E Dirceu, com a lira e o gado?
As altas montanhas duras,
letra a letra, têm contado
sua história aos ternos rios,
que em ouro a têm soletrado…

E as fontes de longe miram
as janelas do sobrado.

Este é o lenço de Marília
para o Amado.

Eis o que resta dos sonhos:
um lenço deixado.

Pombos e flores, presentes.
Mas o resto, arrebatado.

Caiu a folha das árvores,
muita chuva tem gastado
pedras onde houvera lágrimas.
Tudo está mudado.

Este é o lenço de Marília
como foi bordado.
Só nuvens, só muitas nuvens
vêm pousando, têm pousado
entre os desenhos tão finos
de azul e encarnado.
Conta já século e meio
de guardado.

Que amores como este lenço
têm durado,
se este mesmo está durando?
mais que o amor representado?
'''

# %%
texto
# Out:
# '\nEste é o lenço de Marília,\npelas suas mãos lavrado,\nnem a ouro nem a prata,\nsomente a ponto cruzado.\nEste é o lenço de Marília\npara o Amado.\n\nEm cada ponta, um raminho,\npreso num laço encarnado;\nno meio, um cesto de flores,\npor dois pombos transportado.\nNão flores de amor-perfeito,\nmas de malogrado!\n\nEste é o lenço de Marília:\nbem vereis que está manchado:\nserá do tempo perdido?\nserá do tempo passado?\nPela ferrugem das horas?\nou por molhado\nem águas de algum arroio\nsingularmente salgado?\n\nFinos azuis e vermelhos\ndo largo lenço quadrado,\n— quem pintou nuvens tão negras\nneste pano delicado,\nsem dó de flores e de asas\nnem do seu recado?\n\nEste é o lenço de Marília,\npor vento de amor mandado.\nPara viver de suspiros\nfoi pela sorte fadado:\nbreves suspiros de amante,\n— longos, de degredado!\n\nEste é o lenço de Marília\nnele vereis retratado\no destino dos amores\npor um lenço atravessado:\nque o lenço para os adeuses\ne o pranto foi inventado.\n\nOlhai os ramos de flores\nde cada lado!\nE os tristes pombos, no meio,\ncom o seu cestinho parado\nsobre o tempo, sobre as nuvens\ndo mau fado!\n\nOnde está Marília, a bela?\nE Dirceu, com a lira e o gado?\nAs altas montanhas duras,\nletra a letra, têm contado\nsua história aos ternos rios,\nque em ouro a têm soletrado…\n\nE as fontes de longe miram\nas janelas do sobrado.\n\nEste é o lenço de Marília\npara o Amado.\n\nEis o que resta dos sonhos:\num lenço deixado.\n\nPombos e flores, presentes.\nMas o resto, arrebatado.\n\nCaiu a folha das árvores,\nmuita chuva tem gastado\npedras onde houvera lágrimas.\nTudo está mudado.\n\nEste é o lenço de Marília\ncomo foi bordado.\nSó nuvens, só muitas nuvens\nvêm pousando, têm pousado\nentre os desenhos tão finos\nde azul e encarnado.\nConta já século e meio\nde guardado.\n\nQue amores como este lenço\ntêm durado,\nse este mesmo está durando?\nmais que o amor representado?\n'

# %%
import string
texto.split()
# Out:
# ['Este',
#  'é',
#  'o',
#  'lenço',
#  'de',
#  'Marília,',
#  'pelas',
#  'suas',
#  'mãos',
#  'lavrado,',
#  'nem',
#  'a',
#  'ouro',
#  'nem',
#  'a',
#  'prata,',
#  'somente',
#  'a',
#  'ponto',
#  'cruzado.',
#  'Este',
#  'é',
#  'o',
#  'lenço',
#  'de',
#  'Marília',
#  'para',
#  'o',
#  'Amado.',
#  'Em',
#  'cada',
#  'ponta,',
#  'um',
#  'raminho,',
#  'preso',
#  'num',
#  'laço',
#  'encarnado;',
#  'no',
#  'meio,',
#  'um',
#  'cesto',
#  'de',
#  'flores,',
#  'por',
#  'dois',
#  'pombos',
#  'transportado.',
#  'Não',
#  'flores',
#  'de',
#  'amor-perfeito,',
#  'mas',
#  'de',
#  'malogrado!',
#  'Este',
#  'é',
#  'o',
#  'lenço',
#  'de',
#  'Marília:',
#  'bem',
#  'vereis',
#  'que',
#  'está',
#  'manchado:',
#  'será',
#  'do',
#  'tempo',
#  'perdido?',
#  'será',
#  'do',
#  'tempo',
#  'passado?',
#  'Pela',
#  'ferrugem',
#  'das',
#  'horas?',
#  'ou',
#  'por',
#  'molhado',
#  'em',
#  'águas',
#  'de',
#  'algum',
#  'arroio',
#  'singularmente',
#  'salgado?',
#  'Finos',
#  'azuis',
#  'e',
#  'vermelhos',
#  'do',
#  'largo',
#  'lenço',
#  'quadrado,',
#  '—',
#  'quem',
#  'pintou',
#  'nuvens',
#  'tão',
#  'negras',
#  'neste',
#  'pano',
#  'delicado,',
#  'sem',
#  'dó',
#  'de',
#  'flores',
#  'e',
#  'de',
#  'asas',
#  'nem',
#  'do',
#  'seu',
#  'recado?',
#  'Este',
#  'é',
#  'o',
#  'lenço',
#  'de',
#  'Marília,',
#  'por',
#  'vento',
#  'de',
#  'amor',
#  'mandado.',
#  'Para',
#  'viver',
#  'de',
#  'suspiros',
#  'foi',
#  'pela',
#  'sorte',
#  'fadado:',
#  'breves',
#  'suspiros',
#  'de',
#  'amante,',
#  '—',
#  'longos,',
#  'de',
#  'degredado!',
#  'Este',
#  'é',
#  'o',
#  'lenço',
#  'de',
#  'Marília',
#  'nele',
#  'vereis',
#  'retratado',
#  'o',
#  'destino',
#  'dos',
#  'amores',
#  'por',
#  'um',
#  'lenço',
#  'atravessado:',
#  'que',
#  'o',
#  'lenço',
#  'para',
#  'os',
#  'adeuses',
#  'e',
#  'o',
#  'pranto',
#  'foi',
#  'inventado.',
#  'Olhai',
#  'os',
#  'ramos',
#  'de',
#  'flores',
#  'de',
#  'cada',
#  'lado!',
#  'E',
#  'os',
#  'tristes',
#  'pombos,',
#  'no',
#  'meio,',
#  'com',
#  'o',
#  'seu',
#  'cestinho',
#  'parado',
#  'sobre',
#  'o',
#  'tempo,',
#  'sobre',
#  'as',
#  'nuvens',
#  'do',
#  'mau',
#  'fado!',
#  'Onde',
#  'está',
#  'Marília,',
#  'a',
#  'bela?',
#  'E',
#  'Dirceu,',
#  'com',
#  'a',
#  'lira',
#  'e',
#  'o',
#  'gado?',
#  'As',
#  'altas',
#  'montanhas',
#  'duras,',
#  'letra',
#  'a',
#  'letra,',
#  'têm',
#  'contado',
#  'sua',
#  'história',
#  'aos',
#  'ternos',
#  'rios,',
#  'que',
#  'em',
#  'ouro',
#  'a',
#  'têm',
#  'soletrado…',
#  'E',
#  'as',
#  'fontes',
#  'de',
#  'longe',
#  'miram',
#  'as',
#  'janelas',
#  'do',
#  'sobrado.',
#  'Este',
#  'é',
#  'o',
#  'lenço',
#  'de',
#  'Marília',
#  'para',
#  'o',
#  'Amado.',
#  'Eis',
#  'o',
#  'que',
#  'resta',
#  'dos',
#  'sonhos:',
#  'um',
#  'lenço',
#  'deixado.',
#  'Pombos',
#  'e',
#  'flores,',
#  'presentes.',
#  'Mas',
#  'o',
#  'resto,',
#  'arrebatado.',
#  'Caiu',
#  'a',
#  'folha',
#  'das',
#  'árvores,',
#  'muita',
#  'chuva',
#  'tem',
#  'gastado',
#  'pedras',
#  'onde',
#  'houvera',
#  'lágrimas.',
#  'Tudo',
#  'está',
#  'mudado.',
#  'Este',
#  'é',
#  'o',
#  'lenço',
#  'de',
#  'Marília',
#  'como',
#  'foi',
#  'bordado.',
#  'Só',
#  'nuvens,',
#  'só',
#  'muitas',
#  'nuvens',
#  'vêm',
#  'pousando,',
#  'têm',
#  'pousado',
#  'entre',
#  'os',
#  'desenhos',
#  'tão',
#  'finos',
#  'de',
#  'azul',
#  'e',
#  'encarnado.',
#  'Conta',
#  'já',
#  'século',
#  'e',
#  'meio',
#  'de',
#  'guardado.',
#  'Que',
#  'amores',
#  'como',
#  'este',
#  'lenço',
#  'têm',
#  'durado,',
#  'se',
#  'este',
#  'mesmo',
#  'está',
#  'durando?',
#  'mais',
#  'que',
#  'o',
#  'amor',
#  'representado?']

# %%
palavras =[token.lower() for token in texto.split()] 
palavras = [token.lower().strip(string.punctuation) for token in texto.split()]

# %%
texto.count('lenço')
# Out:
# 12

# %%
palavras
# Out:
# ['este',
#  'é',
#  'o',
#  'lenço',
#  'de',
#  'marília',
#  'pelas',
#  'suas',
#  'mãos',
#  'lavrado',
#  'nem',
#  'a',
#  'ouro',
#  'nem',
#  'a',
#  'prata',
#  'somente',
#  'a',
#  'ponto',
#  'cruzado',
#  'este',
#  'é',
#  'o',
#  'lenço',
#  'de',
#  'marília',
#  'para',
#  'o',
#  'amado',
#  'em',
#  'cada',
#  'ponta',
#  'um',
#  'raminho',
#  'preso',
#  'num',
#  'laço',
#  'encarnado',
#  'no',
#  'meio',
#  'um',
#  'cesto',
#  'de',
#  'flores',
#  'por',
#  'dois',
#  'pombos',
#  'transportado',
#  'não',
#  'flores',
#  'de',
#  'amor-perfeito',
#  'mas',
#  'de',
#  'malogrado',
#  'este',
#  'é',
#  'o',
#  'lenço',
#  'de',
#  'marília',
#  'bem',
#  'vereis',
#  'que',
#  'está',
#  'manchado',
#  'será',
#  'do',
#  'tempo',
#  'perdido',
#  'será',
#  'do',
#  'tempo',
#  'passado',
#  'pela',
#  'ferrugem',
#  'das',
#  'horas',
#  'ou',
#  'por',
#  'molhado',
#  'em',
#  'águas',
#  'de',
#  'algum',
#  'arroio',
#  'singularmente',
#  'salgado',
#  'finos',
#  'azuis',
#  'e',
#  'vermelhos',
#  'do',
#  'largo',
#  'lenço',
#  'quadrado',
#  '—',
#  'quem',
#  'pintou',
#  'nuvens',
#  'tão',
#  'negras',
#  'neste',
#  'pano',
#  'delicado',
#  'sem',
#  'dó',
#  'de',
#  'flores',
#  'e',
#  'de',
#  'asas',
#  'nem',
#  'do',
#  'seu',
#  'recado',
#  'este',
#  'é',
#  'o',
#  'lenço',
#  'de',
#  'marília',
#  'por',
#  'vento',
#  'de',
#  'amor',
#  'mandado',
#  'para',
#  'viver',
#  'de',
#  'suspiros',
#  'foi',
#  'pela',
#  'sorte',
#  'fadado',
#  'breves',
#  'suspiros',
#  'de',
#  'amante',
#  '—',
#  'longos',
#  'de',
#  'degredado',
#  'este',
#  'é',
#  'o',
#  'lenço',
#  'de',
#  'marília',
#  'nele',
#  'vereis',
#  'retratado',
#  'o',
#  'destino',
#  'dos',
#  'amores',
#  'por',
#  'um',
#  'lenço',
#  'atravessado',
#  'que',
#  'o',
#  'lenço',
#  'para',
#  'os',
#  'adeuses',
#  'e',
#  'o',
#  'pranto',
#  'foi',
#  'inventado',
#  'olhai',
#  'os',
#  'ramos',
#  'de',
#  'flores',
#  'de',
#  'cada',
#  'lado',
#  'e',
#  'os',
#  'tristes',
#  'pombos',
#  'no',
#  'meio',
#  'com',
#  'o',
#  'seu',
#  'cestinho',
#  'parado',
#  'sobre',
#  'o',
#  'tempo',
#  'sobre',
#  'as',
#  'nuvens',
#  'do',
#  'mau',
#  'fado',
#  'onde',
#  'está',
#  'marília',
#  'a',
#  'bela',
#  'e',
#  'dirceu',
#  'com',
#  'a',
#  'lira',
#  'e',
#  'o',
#  'gado',
#  'as',
#  'altas',
#  'montanhas',
#  'duras',
#  'letra',
#  'a',
#  'letra',
#  'têm',
#  'contado',
#  'sua',
#  'história',
#  'aos',
#  'ternos',
#  'rios',
#  'que',
#  'em',
#  'ouro',
#  'a',
#  'têm',
#  'soletrado…',
#  'e',
#  'as',
#  'fontes',
#  'de',
#  'longe',
#  'miram',
#  'as',
#  'janelas',
#  'do',
#  'sobrado',
#  'este',
#  'é',
#  'o',
#  'lenço',
#  'de',
#  'marília',
#  'para',
#  'o',
#  'amado',
#  'eis',
#  'o',
#  'que',
#  'resta',
#  'dos',
#  'sonhos',
#  'um',
#  'lenço',
#  'deixado',
#  'pombos',
#  'e',
#  'flores',
#  'presentes',
#  'mas',
#  'o',
#  'resto',
#  'arrebatado',
#  'caiu',
#  'a',
#  'folha',
#  'das',
#  'árvores',
#  'muita',
#  'chuva',
#  'tem',
#  'gastado',
#  'pedras',
#  'onde',
#  'houvera',
#  'lágrimas',
#  'tudo',
#  'está',
#  'mudado',
#  'este',
#  'é',
#  'o',
#  'lenço',
#  'de',
#  'marília',
#  'como',
#  'foi',
#  'bordado',
#  'só',
#  'nuvens',
#  'só',
#  'muitas',
#  'nuvens',
#  'vêm',
#  'pousando',
#  'têm',
#  'pousado',
#  'entre',
#  'os',
#  'desenhos',
#  'tão',
#  'finos',
#  'de',
#  'azul',
#  'e',
#  'encarnado',
#  'conta',
#  'já',
#  'século',
#  'e',
#  'meio',
#  'de',
#  'guardado',
#  'que',
#  'amores',
#  'como',
#  'este',
#  'lenço',
#  'têm',
#  'durado',
#  'se',
#  'este',
#  'mesmo',
#  'está',
#  'durando',
#  'mais',
#  'que',
#  'o',
#  'amor',
#  'representado']

# %%
dic = [token.count for token in palavras]

# %%
palavras.count(palavras[11])
# Out:
# 8

# %%
len(palavras)
# Out:
# 335

# %%
for x in range(len(palavras)):
    lista = palavras.count(palavras[x])
    print(palavras[x], lista)
for y in range(len(palavras))
# Out:
# este 9
# é 7
# o 18
# lenço 12
# de 22
# marília 8
# pelas 1
# suas 1
# mãos 1
# lavrado 1
# nem 3
# a 8
# ouro 2
# nem 3
# a 8
# prata 1
# somente 1
# a 8
# ponto 1
# cruzado 1
# este 9
# é 7
# o 18
# lenço 12
# de 22
# marília 8
# para 4
# o 18
# amado 2
# em 3
# cada 2
# ponta 1
# um 4
# raminho 1
# preso 1
# num 1
# laço 1
# encarnado 2
# no 2
# meio 3
# um 4
# cesto 1
# de 22
# flores 5
# por 4
# dois 1
# pombos 3
# transportado 1
# não 1
# flores 5
# de 22
# amor-perfeito 1
# mas 2
# de 22
# malogrado 1
# este 9
# é 7
# o 18
# lenço 12
# de 22
# marília 8
# bem 1
# vereis 2
# que 6
# está 4
# manchado 1
# será 2
# do 6
# tempo 3
# perdido 1
# será 2
# do 6
# tempo 3
# passado 1
# pela 2
# ferrugem 1
# das 2
# horas 1
# ou 1
# por 4
# molhado 1
# em 3
# águas 1
# de 22
# algum 1
# arroio 1
# singularmente 1
# salgado 1
# finos 2
# azuis 1
# e 10
# vermelhos 1
# do 6
# largo 1
# lenço 12
# quadrado 1
# — 2
# quem 1
# pintou 1
# nuvens 4
# tão 2
# negras 1
# neste 1
# pano 1
# delicado 1
# sem 1
# dó 1
# de 22
# flores 5
# e 10
# de 22
# asas 1
# nem 3
# do 6
# seu 2
# recado 1
# este 9
# é 7
# o 18
# lenço 12
# de 22
# marília 8
# por 4
# vento 1
# de 22
# amor 2
# mandado 1
# para 4
# viver 1
# de 22
# suspiros 2
# foi 3
# pela 2
# sorte 1
# fadado 1
# breves 1
# suspiros 2
# de 22
# amante 1
# — 2
# longos 1
# de 22
# degredado 1
# este 9
# é 7
# o 18
# lenço 12
# de 22
# marília 8
# nele 1
# vereis 2
# retratado 1
# o 18
# destino 1
# dos 2
# amores 2
# por 4
# um 4
# lenço 12
# atravessado 1
# que 6
# o 18
# lenço 12
# para 4
# os 4
# adeuses 1
# e 10
# o 18
# pranto 1
# foi 3
# inventado 1
# olhai 1
# os 4
# ramos 1
# de 22
# flores 5
# de 22
# cada 2
# lado 1
# e 10
# os 4
# tristes 1
# pombos 3
# no 2
# meio 3
# com 2
# o 18
# seu 2
# cestinho 1
# parado 1
# sobre 2
# o 18
# tempo 3
# sobre 2
# as 4
# nuvens 4
# do 6
# mau 1
# fado 1
# onde 2
# está 4
# marília 8
# a 8
# bela 1
# e 10
# dirceu 1
# com 2
# a 8
# lira 1
# e 10
# o 18
# gado 1
# as 4
# altas 1
# montanhas 1
# duras 1
# letra 2
# a 8
# letra 2
# têm 4
# contado 1
# sua 1
# história 1
# aos 1
# ternos 1
# rios 1
# que 6
# em 3
# ouro 2
# a 8
# têm 4
# soletrado… 1
# e 10
# as 4
# fontes 1
# de 22
# longe 1
# miram 1
# as 4
# janelas 1
# do 6
# sobrado 1
# este 9
# é 7
# o 18
# lenço 12
# de 22
# marília 8
# para 4
# o 18
# amado 2
# eis 1
# o 18
# que 6
# resta 1
# dos 2
# sonhos 1
# um 4
# lenço 12
# deixado 1
# pombos 3
# e 10
# flores 5
# presentes 1
# mas 2
# o 18
# resto 1
# arrebatado 1
# caiu 1
# a 8
# folha 1
# das 2
# árvores 1
# muita 1
# chuva 1
# tem 1
# gastado 1
# pedras 1
# onde 2
# houvera 1
# lágrimas 1
# tudo 1
# está 4
# mudado 1
# este 9
# é 7
# o 18
# lenço 12
# de 22
# marília 8
# como 2
# foi 3
# bordado 1
# só 2
# nuvens 4
# só 2
# muitas 1
# nuvens 4
# vêm 1
# pousando 1
# têm 4
# pousado 1
# entre 1
# os 4
# desenhos 1
# tão 2
# finos 2
# de 22
# azul 1
# e 10
# encarnado 2
# conta 1
# já 1
# século 1
# e 10
# meio 3
# de 22
# guardado 1
# que 6
# amores 2
# como 2
# este 9
# lenço 12
# têm 4
# durado 1
# se 1
# este 9
# mesmo 1
# está 4
# durando 1
# mais 1
# que 6
# o 18
# amor 2
# representado 1

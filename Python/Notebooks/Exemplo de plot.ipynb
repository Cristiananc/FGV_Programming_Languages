# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-1000, 1001, 1)
y1 = 2*x**2 - 10*x - 32
y0 = np.zeros(2001)

plt.plot(x, y1)
plt.plot(x, y0)
axes = plt.gca()
axes.set_xlim([-5, 10])
axes.set_ylim([-50, 50])
# Out:
# (-50, 50)
